# %% [markdown]
# # Quick Guide to Facebook's Prophet Basics
# ---
# ---
#
# ## IMPORTANT NOTE ONE:
#
# **You should really read the papaer for Prophet! It is relatively straightforward and has a lot of insight on their techniques on how Prophet works internally!**
#
# Link to paper: https://peerj.com/preprints/3190.pdf
# ---
# ---
#
# ## IMPORTANT NOTE TWO:
#
# -----
# ------
#
# * **NOTE: Link to installation instructions:**
#     * https://facebook.github.io/prophet/docs/installation.html#python
#     * SCROLL DOWN UNTIL YOU SEE THE ANACONDA OPTION AT THE BOTTOM OF THE PAGE.
#     * YOU MAY NEED TO INSTALL BOTH **conda install gcc** and **conda install -c conda-forge fbprophet**
#     * PLEASE READ THROUGH THE DOCS AND STACKOERFLOW CAREFULLY BEFORE POSTING INSTALLATION ISSUES TO THE QA FORUMS.
#
# -----
# ----

# %% [markdown]
# ## Load Libraries

# %%
import pandas as pd
from fbprophet import Prophet

# %% [markdown]
# ## Load Data
#
# The input to Prophet is always a dataframe with two columns: ds and y. The ds (datestamp) column should be of a format expected by Pandas, ideally YYYY-MM-DD for a date or YYYY-MM-DD HH:MM:SS for a timestamp. The y column must be numeric, and represents the measurement we wish to forecast.

# %%
import pathlib
path = pathlib.Path(r"C:\Users\saurabhkumar9\15. TimeSeries\Data")

df = pd.read_csv(path/'BeerWineLiquor.csv')

# %%
df.head()
# Out:
#        date  beer
# 0  1/1/1992  1509
# 1  2/1/1992  1541
# 2  3/1/1992  1597
# 3  4/1/1992  1675
# 4  5/1/1992  1822

# %% [markdown]
# ### Format the Data
# Prophet requires date as ds and data as y

# %%
df.columns = ['ds','y']

# %%
# changes ds as datetime object
df['ds'] = pd.to_datetime(df['ds'])

# %% [markdown]
# ## Create and Fit Model

# %%
# This is fitting on all the data (no train test split in this example)
m = Prophet()
m.fit(df)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\saurabhkumar9\AppData\Local\Continuum\anaconda2\envs\spyder\lib\site-packages\pystan\misc.py:399: FutureWarning:
#
# Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.

# %% [markdown]
# ## Forecasting
#
# ### Step 1: Create "future" placeholder dataframe
#
# **NOTE: Prophet by default is for daily data. You need to pass a frequency for sub-daily or monthly data. Info: https://facebook.github.io/prophet/docs/non-daily_data.html**

# %%
future = m.make_future_dataframe(periods=24,freq = 'MS') # set frequency as monthly

# %%
df.tail()
# Out:
#             ds     y
# 319 2018-08-01  4898
# 320 2018-09-01  4598
# 321 2018-10-01  4737
# 322 2018-11-01  5130
# 323 2018-12-01  6370

# %%
future.tail()
# Out:
#             ds
# 343 2020-08-01
# 344 2020-09-01
# 345 2020-10-01
# 346 2020-11-01
# 347 2020-12-01

# %%
len(df)
# Out:
# 324

# %%
len(future)
# Out:
# 348

# %% [markdown]
# ### Step 2: Predict and fill in the Future

# %%
forecast = m.predict(future)

# %%
forecast.head()
# Out:
#           ds        trend   yhat_lower   yhat_upper  trend_lower  trend_upper  \
# 0 1992-01-01  1778.389678  1153.601994  1480.429447  1778.389678  1778.389678
# 1 1992-02-01  1780.987184  1196.606873  1524.000946  1780.987184  1780.987184
# 2 1992-03-01  1783.417109  1438.278355  1761.563893  1783.417109  1783.417109
# 3 1992-04-01  1786.014616  1434.899364  1746.460195  1786.014616  1786.014616
# 4 1992-05-01  1788.528331  1679.845860  1992.283427  1788.528331  1788.528331
#
#    additive_terms  additive_terms_lower  additive_terms_upper      yearly  \
# 0     -461.901459           -461.901459           -461.901459 -461.901459
# 1     -427.924955           -427.924955           -427.924955 -427.924955
# 2     -179.677739           -179.677739           -179.677739 -179.677739
# 3     -196.091481           -196.091481           -196.091481 -196.091481
# 4       45.713009             45.713009             45.713009   45.713009
#
#    yearly_lower  yearly_upper  multiplicative_terms  \
# 0   -461.901459   -461.901459                   0.0
# 1   -427.924955   -427.924955                   0.0
# 2   -179.677739   -179.677739                   0.0
# 3   -196.091481   -196.091481                   0.0
# 4     45.713009     45.713009                   0.0
#
#    multiplicative_terms_lower  multiplicative_terms_upper         yhat
# 0                         0.0                         0.0  1316.488218
# 1                         0.0                         0.0  1353.062229
# 2                         0.0                         0.0  1603.739371
# 3                         0.0                         0.0  1589.923135
# 4                         0.0                         0.0  1834.241340

# %%
forecast.tail()
# Out:
#             ds        trend   yhat_lower   yhat_upper  trend_lower  \
# 343 2020-08-01  5204.920380  5084.234482  5404.743324  5191.248136
# 344 2020-09-01  5221.075787  4924.968686  5250.959609  5206.421112
# 345 2020-10-01  5236.710051  5035.240890  5351.578322  5220.741334
# 346 2020-11-01  5252.865458  5168.618162  5499.658360  5236.048460
# 347 2020-12-01  5268.499722  6176.763330  6508.253371  5250.811122
#
#      trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 343  5217.705718       40.765082             40.765082             40.765082
# 344  5234.879910     -132.510619           -132.510619           -132.510619
# 345  5251.614425      -43.280888            -43.280888            -43.280888
# 346  5268.892551       87.236362             87.236362             87.236362
# 347  5285.862552     1071.594904           1071.594904           1071.594904
#
#           yearly  yearly_lower  yearly_upper  multiplicative_terms  \
# 343    40.765082     40.765082     40.765082                   0.0
# 344  -132.510619   -132.510619   -132.510619                   0.0
# 345   -43.280888    -43.280888    -43.280888                   0.0
# 346    87.236362     87.236362     87.236362                   0.0
# 347  1071.594904   1071.594904   1071.594904                   0.0
#
#      multiplicative_terms_lower  multiplicative_terms_upper         yhat
# 343                         0.0                         0.0  5245.685462
# 344                         0.0                         0.0  5088.565168
# 345                         0.0                         0.0  5193.429163
# 346                         0.0                         0.0  5340.101820
# 347                         0.0                         0.0  6340.094626

# %%
forecast.columns
# Out:
# Index(['ds', 'trend', 'yhat_lower', 'yhat_upper', 'trend_lower', 'trend_upper',
#        'additive_terms', 'additive_terms_lower', 'additive_terms_upper',
#        'yearly', 'yearly_lower', 'yearly_upper', 'multiplicative_terms',
#        'multiplicative_terms_lower', 'multiplicative_terms_upper', 'yhat'],
#       dtype='object')

# %%
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(12)
# Out:
#             ds         yhat   yhat_lower   yhat_upper
# 336 2020-01-01  4632.015644  4475.446242  4794.774103
# 337 2020-02-01  4682.147555  4524.727984  4837.605881
# 338 2020-03-01  4945.507893  4787.082973  5094.170593
# 339 2020-04-01  4945.249558  4786.373674  5109.641996
# 340 2020-05-01  5202.688312  5031.251105  5354.061337
# 341 2020-06-01  5183.565324  5031.556729  5345.470331
# 342 2020-07-01  5316.228164  5152.210937  5461.640329
# 343 2020-08-01  5245.685462  5084.234482  5404.743324
# 344 2020-09-01  5088.565168  4924.968686  5250.959609
# 345 2020-10-01  5193.429163  5035.240890  5351.578322
# 346 2020-11-01  5340.101820  5168.618162  5499.658360
# 347 2020-12-01  6340.094626  6176.763330  6508.253371

# %% [markdown]
# ### Plotting Forecast
#
# We can use Prophet's own built in plotting tools

# %%
m.plot(forecast);

# %%
import matplotlib.pyplot as plt
pd.plotting.register_matplotlib_converters()
m.plot(forecast)
plt.xlim('2014-01-01','2021-01-01')
# Out:
# (735234.0, 737791.0)

# %%
pd.plotting.register_matplotlib_converters()
forecast.plot(x=0, y = 1, kind = 'line')

# %%
forecast.dtypes
# Out:
# ds                            datetime64[ns]
# trend                                float64
# yhat_lower                           float64
# yhat_upper                           float64
# trend_lower                          float64
# trend_upper                          float64
# additive_terms                       float64
# additive_terms_lower                 float64
# additive_terms_upper                 float64
# yearly                               float64
# yearly_lower                         float64
# yearly_upper                         float64
# multiplicative_terms                 float64
# multiplicative_terms_lower           float64
# multiplicative_terms_upper           float64
# yhat                                   int64
# dtype: object

# %%
m.plot_components(forecast);
